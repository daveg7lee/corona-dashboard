# %%
import pandas as pd

conditions = ["confirmed", "deaths", "recovered"]

def make_country_df(condition, country):
    df = pd.read_csv(f"data/time_{condition}.csv")
    df = df.loc[df["Country/Region"] == country]
    df = df.drop(columns=["Province/State", "Country/Region", "Lat", "Long"]).sum().reset_index(name=condition)
    df = df.rename(columns={"index":"date"})
    return df

final_df = None

for condition in conditions:
    condition_df = make_country_df(condition, "Korea, South")
    if final_df is None:
        final_df = condition_df
    else:
        final_df = final_df.merge(condition_df)
        
final_df
# Out:
#         date  confirmed  deaths  recovered
# 0    1/22/20          1       0          0
# 1    1/23/20          1       0          0
# 2    1/24/20          2       0          0
# 3    1/25/20          2       0          0
# 4    1/26/20          3       0          0
# ..       ...        ...     ...        ...
# 457  4/23/21     118243    1812     107781
# 458  4/24/21     118887    1813     108475
# 459  4/25/21     119387    1817     108850
# 460  4/26/21     119898    1820     109695
# 461  4/27/21     120673    1821     110248
#
# [462 rows x 4 columns]
